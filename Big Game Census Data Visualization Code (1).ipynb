# %% [markdown]
# ## Big Game Census Data Visualization

# %%
#Import libraries

import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) 
pd.options.mode.chained_assignment = None

#Read the data
df=pd.read_csv(r'E:\Data Science\Internship\iNeuron\uscensusbureau-big-game-census-data-visualization\uscensusbureau-big-game-census-data-visualization\Big Game Census data.csv',encoding='latin-1')
df.head()
# Out:
#       Player Name Player Jersey Number Player Position  Player Age  \
# 0  James Harrison                  #92          LB/RDE        39.0
# 1    Brandon King                  #36       S/FS/SPTM        24.0
# 2      Dion Lewis                  #33           RB/KR        27.0
# 3     Alan Branch                  #97          DT/LDT        33.0
# 4  Chance Warmack                  #67           G/LOG        26.0
#
#    Player Weight (lbs.) Years Played Player Birthplace (city, town, etc.)  \
# 0                 242.0           15                                Akron
# 1                 220.0            3                            Alabaster
# 2                 195.0            6                               Albany
# 3                 350.0           11                          Albuquerque
# 4                 323.0            5                              Atlanta
#
#   Player Birth State Player Birthplace (Combo) Player College  ...  \
# ...

# %%
df.shape
# Out:
# (121, 24)

# %%
#returns %age of missing data in each column
for col in df.columns:
    pct_missing=np.mean(df[col].isnull())
    print('{} - {}%'.format(col,pct_missing))
# Out:
# Player Name - 0.01652892561983471%
# Player Jersey Number - 0.024793388429752067%
# Player Position - 0.024793388429752067%
# Player Age - 0.024793388429752067%
# Player Weight (lbs.) - 0.024793388429752067%
# Years Played - 0.024793388429752067%
# Player Birthplace (city, town, etc.) - 0.024793388429752067%
# Player Birth State - 0.024793388429752067%
# Player Birthplace (Combo) - 0.024793388429752067%
# Player College - 0.024793388429752067%
# Player Team - 0.024793388429752067%
# Conference - 0.024793388429752067%
# 2016 Population Estimates (except where otherwise noted) - 0.024793388429752067%
# State GEO ID - 0.024793388429752067%
# Full GEOID - 0.024793388429752067%
# Latitude (player birthplace) - 0.024793388429752067%
# Longitude (player birthplace) - 0.024793388429752067%
# Number from City - 0.024793388429752067%
# Number of Records - 0.024793388429752067%
# American FactFinder Link for more Census data points - 0.024793388429752067%
# ...

# %%
df.dtypes
# Out:
# Player Name                                                  object
# Player Jersey Number                                         object
# Player Position                                              object
# Player Age                                                  float64
# Player Weight (lbs.)                                        float64
# Years Played                                                 object
# Player Birthplace (city, town, etc.)                         object
# Player Birth State                                           object
# Player Birthplace (Combo)                                    object
# Player College                                               object
# Player Team                                                  object
# Conference                                                   object
# 2016 Population Estimates (except where otherwise noted)     object
# State GEO ID                                                float64
# ...

# %%
df.isnull().sum()
# Out:
# Player Name                                                 2
# Player Jersey Number                                        3
# Player Position                                             3
# Player Age                                                  3
# Player Weight (lbs.)                                        3
# Years Played                                                3
# Player Birthplace (city, town, etc.)                        3
# Player Birth State                                          3
# Player Birthplace (Combo)                                   3
# Player College                                              3
# Player Team                                                 3
# Conference                                                  3
# 2016 Population Estimates (except where otherwise noted)    3
# State GEO ID                                                3
# Full GEOID                                                  3
# ...

# %%
df=df.dropna(how='all')
#how='all': means drop the entire row where there is missing value
df.shape
# Out:
# (119, 24)

# %%
df.corr()
# Out:
#                                Player Age  Player Weight (lbs.)  State GEO ID  \
# Player Age                       1.000000             -0.016997      0.027805
# Player Weight (lbs.)            -0.016997              1.000000      0.163214
# State GEO ID                     0.027805              0.163214      1.000000
# Latitude (player birthplace)     0.085980             -0.033874      0.005716
# Longitude (player birthplace)    0.083444             -0.136517      0.251143
# Number from City                 0.049584             -0.147419     -0.082166
# Number of Records                     NaN                   NaN           NaN
#
#                                Latitude (player birthplace)  \
# Player Age                                         0.085980
# Player Weight (lbs.)                              -0.033874
# State GEO ID                                       0.005716
# Latitude (player birthplace)                       1.000000
# ...

# %% [markdown]
# #### Conclusion: Null values are removed from the data and the data is now ready to be visualized on Tableau. No correlation is found within the data.
